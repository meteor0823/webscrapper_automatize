# %%
import requests
import pandas as pd

# ====== 你的凭证 ======
APP_ID = "abfa41a4"
APP_KEY = "35ab524c83cf1d5f5a7566388892f9c5"

# ====== API endpoint ======
url = "https://api.adzuna.com/v1/api/jobs/us/search/1"

params = {
    "app_id": APP_ID,
    "app_key": APP_KEY,
    "results_per_page": 50,
    # "what": "economist",
    "content-type": "application/json"
}

# ====== 请求 ======
r = requests.get(url, params=params)
r.raise_for_status()

data = r.json()

# %%
print(data)
# Out:
# {'mean': 71235.49, '__CLASS__': 'Adzuna::API::Response::JobSearchResults', 'count': 6902688, 'results': [{'salary_max': 70736.41, 'description': "Regional Class A CDL Drivers - $1,400 - $1,600 weekly pay Dive into a career that offers a job and a lifestyle where your efforts are recognized, and your success is celebrated. At Premier, we’ve built a culture that supports our team on and off the road. If you're 22 or older, have a Class A CDL, and have at least one year of tractor-trailer experience, we want to hear from you! Apply today and see why many drivers have found their home at Premier Transportation. Let’s drive towards success to…", '__CLASS__': 'Adzuna::API::Response::Job', 'title': 'Regional Class A CDL Drivers', 'salary_min': 70736.41, 'redirect_url': 'https://www.adzuna.com/land/ad/5615830531?se=gntg4ZcD8RGHQIx1fmINKQ&utm_medium=api&utm_source=abfa41a4&v=002123E28B99D2B912B07202309CCEC0713DFC44', 'company': {'display_name': 'Premier Transportation', '__CLASS__': 'Adzuna::API::Response::Company'}, 'created': '2026-02-05T13:37:37Z', 'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJzIjoiZ250ZzRaY0Q4UkdIUUl4MWZtSU5LUSIsImkiOiI1NjE1ODMwNTMxIn0.0hpek_I6rsNNw2CWARfk6Tmdn8gFob4MdcyNPy89IAE', 'location': {'display_name': 'Jackson, Butts County', '__CLASS__': 'Adzuna::API::Response::Location', 'area': ['US', 'Georgia', 'Butts County', 'Jackson']}, 'id': '5615830531', 'longitude': -83.978035, 'contract_time': 'full_time', 'salary_is_predicted': '1', 'category': {'__CLASS__': 'Adzuna::API::Response::Category', 'tag': 'logistics-warehouse-jobs', 'label': 'Logistics & Warehouse Jobs'}, 'latitude': 33.290906}, {'salary_is_predicted': '1', 'category': {'label': 'Healthcare & Nursing Jobs', 'tag': 'healthcare-nursing-jobs', '__CLASS__': 'Adzuna::API::Response::Category'}, 'id': '5615581655', 'longitude': -82.478957, 'contract_time': 'part_time', 'latitude': 35.326974, 'location': {'area': ['US', 'North Carolina', 'Henderson County', 'Laurel Park'], 'display_name': 'Laurel Park, Henderson County', '__CLASS__': 'Adzuna::API::Response::Location'}, 'adref': 'eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTYxNTU4MTY1NSIsInMiOiJnbnRnNFpjRDhSR0hRSXgxZm1JTktRIn0.8lj7NaMyjFHj8wHuMJx-OIRC6yjJoDZlIE8ZDuMJJEc', 'created': '2026-02-05T06:13:38Z', 'company': {'__CLASS__': 'Adzuna::API::Response::Company', 'display_name': 'Agape Care Group'}, 'salary_min': 65047.89, 'redirect_url': 'https://www.adzuna.com/land/ad/5615581655?se=gntg4ZcD8RGHQIx1fmINKQ&utm_medium=api&utm_source=abfa41a4&v=99B58E938BF06387F8177EBB40CC062509D114E9', 'description': 'Overview: Join Our Team as a Pediatric Registered Nurse Do you value the time you spend with your patients? Is it important to you that your patients and their families know and feel that you are with them? We are looking for registered nurses to join our team who are committed to creating meaningful patient experiences. As a pediatric registered nurse with Hands of Hope, our pediatric program, you’ll evaluate patients and create care plans, all while communicating with everyone involved — the …', '__CLASS__': 'Adzuna::API::Response::Job', 'salary_max': 65047.89, 'title': 'Pediatric Registered Nurse (RN) PRN'}, {'company': {'__CLASS__': 'Adzuna::API::Response::Company', 'display_name': 'Milton Hershey School'}, 'title': 'Houseparents - Relocation to Hershey, PA Required', '__CLASS__': 'Adzuna::API::Response::Job', 'description': 'Description: Located in Hershey, PA, Milton Hershey School (MHS) is a top-notch home and school where over 2,200 pre-K through 12th grade students from disadvantaged backgrounds are provided an extraordinary, cost-free, career-focused education. This is made possible by the generosity of Milton and Catherine Hershey, who established the school in 1909 and ensured it was fully endowed. Thanks to their foresight and generosity, the school has over 12,000 graduates and continues to expand to serve…', 'salary_max': 92625.55, 'salary_min': 92625.55, 'redirect_url': 'https://www.adzuna.com/land/ad/5428699808?se=gntg4Zc ...

# %%
# ====== 核心数据在 results 里 ======
df = pd.json_normalize(data["results"])

# ====== 导出 ======
df.to_csv("~/Desktop/adzuna_jobs.csv", index=False)

print(f"Saved {len(df)} jobs")
# Out:
# Saved 50 jobs
